# %%
import gymnasium as gym
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Normal
import matplotlib.pyplot as plt
import sys
import copy
# %matplotlib inline

# %% [markdown]
# We provide you with the following utility functions for this assignment: (1) the replay buffer for experience replay, and (2) a policy evaluation function which evaluates a policy with Monte Carlo.

# %%
# Replay buffer
class ReplayBuffer(object):
	def __init__(self, state_dim, action_dim, max_size=int(1e6)):
		self.max_size = max_size
		self.ptr = 0
		self.size = 0

		self.state = np.zeros((max_size, state_dim))
		self.action = np.zeros((max_size, action_dim))
		self.next_state = np.zeros((max_size, state_dim))
		self.reward = np.zeros((max_size, 1))
		self.not_done = np.zeros((max_size, 1))

		self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


	def add(self, state, action, next_state, reward, done):
		self.state[self.ptr] = state
		self.action[self.ptr] = action
		self.next_state[self.ptr] = next_state
		self.reward[self.ptr] = reward
		self.not_done[self.ptr] = 1. - done

		self.ptr = (self.ptr + 1) % self.max_size
		self.size = min(self.size + 1, self.max_size)


	def sample(self, batch_size):
		ind = np.random.randint(0, self.size, size=batch_size)

		return (
			torch.FloatTensor(self.state[ind]).to(self.device),
			torch.FloatTensor(self.action[ind]).to(self.device),
			torch.FloatTensor(self.next_state[ind]).to(self.device),
			torch.FloatTensor(self.reward[ind]).to(self.device),
			torch.FloatTensor(self.not_done[ind]).to(self.device)
		)

# policy evaluation with Monte Carlo
def eval_policy(policy, env_name, seed, eval_episodes=10):
		eval_env = gym.make(env_name)
		eval_env.reset(seed=seed)
		avg_reward = 0.
		for _ in range(eval_episodes):
			state, _ = eval_env.reset()
			done = False
			step = 0
			while not done:
				action = policy.select_action(np.array(state))
				state, reward, terminated, truncated, _ = eval_env.step(action)
				avg_reward += reward
				step += 1
				done = terminated or truncated
		avg_reward /= eval_episodes

		print("---------------------------------------")
		print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
		print("---------------------------------------")
		return avg_reward

# %% [markdown]
# # Twin Delayed Deep Deterministic Policy Gradients (TD3)
#
#
# Recall in last homework we have implemented a TD3 algorithm. You don't need to fill anything here for TD3, we use it as comparison with Soft Actor Critic (SAC) later.

# %%
# Implementation of Twin Delayed Deep Deterministic Policy Gradients (TD3)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class Actor_TD3(nn.Module):
	def __init__(self, state_dim, action_dim, max_action):
		super(Actor_TD3, self).__init__()

		self.l1 = nn.Linear(state_dim, 256)
		self.l2 = nn.Linear(256, 256)
		self.l3 = nn.Linear(256, action_dim)

		self.max_action = max_action


	def forward(self, state):
		a = F.relu(self.l1(state))
		a = F.relu(self.l2(a))
		return self.max_action * torch.tanh(self.l3(a))


class Critic_TD3(nn.Module):
	def __init__(self, state_dim, action_dim):
		super(Critic_TD3, self).__init__()

		# Q1 architecture
		self.l1 = nn.Linear(state_dim + action_dim, 256)
		self.l2 = nn.Linear(256, 256)
		self.l3 = nn.Linear(256, 1)

		# Q2 architecture
		self.l4 = nn.Linear(state_dim + action_dim, 256)
		self.l5 = nn.Linear(256, 256)
		self.l6 = nn.Linear(256, 1)


	def forward(self, state, action):
		sa = torch.cat([state, action], 1)
		q1 = F.relu(self.l1(sa))
		q1 = F.relu(self.l2(q1))
		q1 = self.l3(q1)

		q2 = F.relu(self.l4(sa))
		q2 = F.relu(self.l5(q2))
		q2 = self.l6(q2)
		return q1, q2


	def Q1(self, state, action):
		sa = torch.cat([state, action], 1)

		q1 = F.relu(self.l1(sa))
		q1 = F.relu(self.l2(q1))
		q1 = self.l3(q1)
		return q1


class TD3(object):
	def __init__(
		self,
		state_dim,
		action_dim,
		max_action,
		discount=0.99,
		tau=0.005,
		policy_noise=0.2,
		noise_clip=0.5,
		policy_freq=2
	):

		self.actor = Actor_TD3(state_dim, action_dim, max_action).to(device)
		self.actor_target = copy.deepcopy(self.actor)
		self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=3e-4)

		self.critic = Critic_TD3(state_dim, action_dim).to(device)
		self.critic_target = copy.deepcopy(self.critic)
		self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=3e-4)

		self.max_action = max_action
		self.discount = discount
		self.tau = tau
		self.policy_noise = policy_noise
		self.noise_clip = noise_clip
		self.policy_freq = policy_freq
		self.total_it = 0


	def select_action(self, state):
		state = torch.FloatTensor(state.reshape(1, -1)).to(device)
		return self.actor(state).cpu().data.numpy().flatten()


	def train(self, replay_buffer, batch_size=256):
		self.total_it += 1

		# Sample replay buffer
		state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

		with torch.no_grad():
			# Select action according to policy and add clipped noise
			noise = (
				torch.randn_like(action) * self.policy_noise
			).clamp(-self.noise_clip, self.noise_clip)

			next_action = (
				self.actor_target(next_state) + noise
			).clamp(-self.max_action, self.max_action)

			# Compute the target Q value
			target_Q1, target_Q2 = self.critic_target(next_state, next_action)

			# Compute the target_Q here
			target_Q = torch.min(target_Q1, target_Q2)
			target_Q = reward + not_done * self.discount * target_Q

		# Get current Q estimates
		current_Q1, current_Q2 = self.critic(state, action)

		# Compute critic loss
		critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

		# Optimize the critic
		self.critic_optimizer.zero_grad()
		critic_loss.backward()
		self.critic_optimizer.step()

		# Delayed policy updates
		if self.total_it % self.policy_freq == 0:

			# Compute actor loss
			actor_loss = -self.critic.Q1(state, self.actor(state)).mean()

			# Optimize the actor
			self.actor_optimizer.zero_grad()
			actor_loss.backward()
			self.actor_optimizer.step()

			# Update the frozen target models
			for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

			for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

# %% [markdown]
# # Soft Actor Critic (SAC)
# You will implement the SAC algorithm below.

# %%
LOG_STD_MIN = -20
LOG_STD_MAX = 2
epsilon = 1e-6

class Actor_SAC(nn.Module):
	def __init__(self, state_dim, action_dim, max_action):
		super(Actor_SAC, self).__init__()

		self.l1 = nn.Linear(state_dim, 256)
		self.l2 = nn.Linear(256, 256)
		self.mean = nn.Linear(256, action_dim)
		self.log_std = nn.Linear(256, action_dim)
		self.max_action = max_action

	def forward(self, state):
		a = F.relu(self.l1(state))
		a = F.relu(self.l2(a))
		mean = self.mean(a)
		log_std = self.log_std(a)
		log_std = torch.clamp(log_std, min=LOG_STD_MIN, max=LOG_STD_MAX)
		return mean, log_std

	def sample(self, state):
		mean, log_std = self.forward(state)
		std = log_std.exp()
		normal = Normal(mean, std)
		x = normal.rsample()
		y = torch.tanh(x)
		action = y * self.max_action
		log_prob = normal.log_prob(x)
		log_prob -= torch.log(self.max_action * (1 - y.pow(2)) + epsilon)
		log_prob = log_prob.sum(1, keepdim=True)
		return action, log_prob

class Critic_SAC(nn.Module):
	def __init__(self, state_dim, action_dim):
		super(Critic_SAC, self).__init__()

		# Q1 architecture
		self.l1 = nn.Linear(state_dim + action_dim, 256)
		self.l2 = nn.Linear(256, 256)
		self.l3 = nn.Linear(256, 1)

		# Q2 architecture
		self.l4 = nn.Linear(state_dim + action_dim, 256)
		self.l5 = nn.Linear(256, 256)
		self.l6 = nn.Linear(256, 1)

	def forward(self, state, action):
		sa = torch.cat([state, action], 1)
		q1 = F.relu(self.l1(sa))
		q1 = F.relu(self.l2(q1))
		q1 = self.l3(q1)

		q2 = F.relu(self.l4(sa))
		q2 = F.relu(self.l5(q2))
		q2 = self.l6(q2)
		return q1, q2


	def Q1(self, state, action):
		sa = torch.cat([state, action], 1)

		q1 = F.relu(self.l1(sa))
		q1 = F.relu(self.l2(q1))
		q1 = self.l3(q1)
		return q1

class SAC(object):
	def __init__(
		self,
		state_dim,
		action_dim,
		max_action,
		discount=0.99,
		tau=0.005,
		alpha=0.2,
	):
		self.actor = Actor_SAC(state_dim, action_dim, max_action).to(device)
		self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=3e-4)

		self.critic = Critic_SAC(state_dim, action_dim).to(device)
		self.critic_target = copy.deepcopy(self.critic)
		self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=3e-4)

		self.max_action = max_action
		self.discount = discount
		self.tau = tau
		self.alpha = alpha

	def select_action(self, state):
		state = torch.FloatTensor(state.reshape(1, -1)).to(device)
		action, _ = self.actor.sample(state)
		return action.detach().cpu().numpy().flatten()

	def train(self, replay_buffer, batch_size=256):
		state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

		with torch.no_grad():
			next_action, next_log_prob = self.actor.sample(next_state)
			next_Q1, next_Q2 = self.critic_target(next_state, next_action)

			next_Q = torch.min(next_Q1, next_Q2) - next_log_prob * self.alpha
			target_Q = reward + not_done * self.discount * next_Q

		Q1, Q2 = self.critic(state, action)
		Q1_loss = F.mse_loss(Q1, target_Q)
		Q2_loss = F.mse_loss(Q2, target_Q)
		critic_loss = Q1_loss + Q2_loss

		self.critic_optimizer.zero_grad()
		critic_loss.backward()
		self.critic_optimizer.step()

		action, log_prob = self.actor.sample(state)
		Q1, Q2 = self.critic(state, action)
		Q = torch.min(Q1, Q2)
		actor_loss = ((self.alpha * log_prob) - Q).mean()

		self.actor_optimizer.zero_grad()
		actor_loss.backward()
		self.actor_optimizer.step()

		for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
			target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

# %%
def init_flags():

		flags = {
				"env": "Pendulum-v1",	# previous "MountainCarContinuous-v0"
				"seed":0,
				"start_timesteps": 1e4,
				"max_timesteps": 5e4,
				"expl_noise": 0.01,
				"batch_size": 256,
				"discount":0.99,
				"tau": 0.005,
				"policy_noise": 0.05,
				"noise_clip":0.5,
				"policy_freq": 2,
				"save_model": "store_true"
		}

		return flags

def main(policy_name = 'TD3'):

		args = init_flags()
		env = gym.make(args["env"])
		env.reset(seed=args["seed"])
		env.action_space.seed(args["seed"])
		torch.manual_seed(args["seed"])
		np.random.seed(args["seed"])

		state_dim = env.observation_space.shape[0]
		action_dim = env.action_space.shape[0]
		max_action = float(env.action_space.high[0])
		kwargs = {
				"state_dim": state_dim,
				"action_dim": action_dim,
				"max_action": max_action,
				"discount": args["discount"],
				"tau": args["tau"],}
		if policy_name == "TD3":
				# Target policy smoothing is scaled wrt the action scale
				kwargs["policy_noise"] = args["policy_noise"] * max_action
				kwargs["noise_clip"] = args["noise_clip"] * max_action
				kwargs["policy_freq"] = args["policy_freq"]
				policy = TD3(**kwargs)
		elif policy_name == "SAC":
				policy = SAC(**kwargs)

		replay_buffer = ReplayBuffer(state_dim, action_dim)
		evaluations = [eval_policy(policy, args["env"], args["seed"])]
		state, _ = env.reset()
		done = False
		episode_reward = 0
		episode_timesteps = 0
		episode_num = 0

		for t in range(int(args["max_timesteps"])):
			episode_timesteps += 1

			# Select action randomly or according to policy
			if t < args["start_timesteps"]:
				action = env.action_space.sample()
			else:
				action = (
					policy.select_action(np.array(state))
					+ np.random.normal(0, max_action * args["expl_noise"], size=action_dim)
				).clip(-max_action, max_action)

			# Perform action
			next_state, reward, terminated, truncated, _ = env.step(action)
			done = terminated or truncated
			done_bool = float(done) if episode_timesteps < env._max_episode_steps else 0

			# Store data in replay buffer
			replay_buffer.add(state, action, next_state, reward, done_bool)

			state = next_state
			episode_reward += reward

			# Train agent after collecting sufficient data
			if t >= args["start_timesteps"]:
				policy.train(replay_buffer, args["batch_size"])

			if done:
				# +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
				print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")

				evaluations.append(episode_reward)

				# Reset environment
				state, _ = env.reset()
				done = False
				episode_reward = 0
				episode_timesteps = 0
				episode_num += 1

		return evaluations

# %%
evaluation_td3 = main(policy_name = 'TD3')
# Out:
# ---------------------------------------
# Evaluation over 10 episodes: -1497.954
# ---------------------------------------
# Total T: 200 Episode Num: 1 Episode T: 200 Reward: -1760.738
# Total T: 400 Episode Num: 2 Episode T: 200 Reward: -1246.740
# Total T: 600 Episode Num: 3 Episode T: 200 Reward: -897.289
# Total T: 800 Episode Num: 4 Episode T: 200 Reward: -972.564
# Total T: 1000 Episode Num: 5 Episode T: 200 Reward: -1352.820
# Total T: 1200 Episode Num: 6 Episode T: 200 Reward: -1627.902
# Total T: 1400 Episode Num: 7 Episode T: 200 Reward: -1354.618
# Total T: 1600 Episode Num: 8 Episode T: 200 Reward: -1337.542
# Total T: 1800 Episode Num: 9 Episode T: 200 Reward: -1194.016
# Total T: 2000 Episode Num: 10 Episode T: 200 Reward: -1567.426
# Total T: 2200 Episode Num: 11 Episode T: 200 Reward: -1156.882
# Total T: 2400 Episode Num: 12 Episode T: 200 Reward: -871.624
# Total T: 2600 Episode Num: 13 Episode T: 200 Reward: -1535.508
# Total T: 2800 Episode Num: 14 Episode T: 200 Reward: -970.373
# Total T: 3000 Episode Num: 15 Episode T: 200 Reward: -971.561
# Total T: 3200 Episode Num: 16 Episode T: 200 Reward: -1446.848
# Total T: 3400 Episode Num: 17 Episode T: 200 Reward: -693.019
# Total T: 3600 Episode Num: 18 Episode T: 200 Reward: -879.178
# Total T: 3800 Episode Num: 19 Episode T: 200 Reward: -1662.723
# Total T: 4000 Episode Num: 20 Episode T: 200 Reward: -876.022
# Total T: 4200 Episode Num: 21 Episode T: 200 Reward: -870.474
# Total T: 4400 Episode Num: 22 Episode T: 200 Reward: -906.223
# Total T: 4600 Episode Num: 23 Episode T: 200 Reward: -1278.594
# Total T: 4800 Episode Num: 24 Episode T: 200 Reward: -1616.944
# Total T: 5000 Episode Num: 25 Episode T: 200 Reward: -1349.293
# Total T: 5200 Episode Num: 26 Episode T: 200 Reward: -1528.146
# Total T: 5400 Episode Num: 27 Episode T: 200 Reward: -1116.436
# Total T: 5600 Episode Num: 28 Episode T: 200 Reward: -747.207
# Total T: 5800 Episode Num: 29 Episode T: 200 Reward: -1100.620
# Total T: 6000 Episode Num: 30 Episode T: 200 Reward: -885.808
# Total T: 6200 Episode Num: 31 Episode T: 200 Reward: -1354.708
# Total T: 6400 Episode Num: 32 Episode T: 200 Reward: -992.211
# Total T: 6600 Episode Num: 33 Episode T: 200 Reward: -1357.316
# Total T: 6800 Episode Num: 34 Episode T: 200 Reward: -941.924
# Total T: 7000 Episode Num: 35 Episode T: 200 Reward: -969.479
# Total T: 7200 Episode Num: 36 Episode T: 200 Reward: -891.210
# Total T: 7400 Episode Num: 37 Episode T: 200 Reward: -770.540
# Total T: 7600 Episode Num: 38 Episode T: 200 Reward: -1212.595
# Total T: 7800 Episode Num: 39 Episode T: 200 Reward: -1740.751
# Total T: 8000 Episode Num: 40 Episode T: 200 Reward: -1355.294
# Total T: 8200 Episode Num: 41 Episode T: 200 Reward: -970.389
# Total T: 8400 Episode Num: 42 Episode T: 200 Reward: -752.059
# Total T: 8600 Episode Num: 43 Episode T: 200 Reward: -1181.886
# Total T: 8800 Episode Num: 44 Episode T: 200 Reward: -1566.919
# Total T: 9000 Episode Num: 45 Episode T: 200 Reward: -1548.711
# Total T: 9200 Episode Num: 46 Episode T: 200 Reward: -1661.898
# Total T: 9400 Episode Num: 47 Episode T: 200 Reward: -1513.122
# Total T: 9600 Episode Num: 48 Episode T: 200 Reward: -1287.683
# Total T: 9800 Episode Num: 49 Episode T: 200 Reward: -1552.121
# Total T: 10000 Episode Num: 50 Episode T: 200 Reward: -986.745
# Total T: 10200 Episode Num: 51 Episode T: 200 Reward: -1537.804
# Total T: 10400 Episode Num: 52 Episode T: 200 Reward: -1665.376
# Total T: 10600 Episode Num: 53 Episode T: 200 Reward: -1658.792
# Total T: 10800 Episode Num: 54 Episode T: 200 Reward: -1932.412
# Total T: 11000 Episode Num: 55 Episode T: 200 Reward: -1470.874
# Total T: 11200 Episode Num: 56 Episode T: 200 Reward: -1488.096
# Total T: 11400 Episode Num: 57 Episode T: 200 Reward: -1488.014
# Total T: 11600 Episode Num: 58 Episode T: 200 Reward: -1497.196
# Total T: 11800 Episode Num: 59 Episode T: 200 Reward: -1513.209
# Total T: 12000 Episode Num: 60 Episode T: 200 Reward: -1421.550
# Total T: 12200 Episode Num: 61 Episode T: 200 Reward: -1494.570
# Total T: 12400 Episode Num: 62 Episode T: 200 Reward: -1320.225
# Total T: 12600 Episode Num: 63 Episode T: 200 Reward: -1512.238
# Total T: 12800 Episode Num: 64 Episode T: 200 Reward: -1245.850
# Total T: 13000 Episode Num: 65 Episode T: 200 Reward: -1075.042
# Total T: 13200 Episode Num: 66 Episode T: 200 Reward: -1103.475
# Total T: 13400 Episode Num: 67 Episode T: 200 Reward: -1047.075
# Total T: 13600 Episode Num: 68 Episode T: 200 Reward: -975.323
# Total T: 13800 Episode Num: 69 Episode T: 200 Reward: -1494.047
# Total T: 14000 Episode Num: 70 Episode T: 200 Reward: -781.372
# Total T: 14200 Episode Num: 71 Episode T: 200 Reward: -826.223
# Total T: 14400 Episode Num: 72 Episode T: 200 Reward: -9.998
# Total T: 14600 Episode Num: 73 Episode T: 200 Reward: -567.293
# Total T: 14800 Episode Num: 74 Episode T: 200 Reward: -3.274
# Total T: 15000 Episode Num: 75 Episode T: 200 Reward: -394.387
# Total T: 15200 Episode Num: 76 Episode T: 200 Reward: -1495.338
# Total T: 15400 Episode Num: 77 Episode T: 200 Reward: -130.404
# Total T: 15600 Episode Num: 78 Episode T: 200 Reward: -352.573
# Total T: 15800 Episode Num: 79 Episode T: 200 Reward: -273.927
# Total T: 16000 Episode Num: 80 Episode T: 200 Reward: -127.605
# Total T: 16200 Episode Num: 81 Episode T: 200 Reward: -0.825
# Total T: 16400 Episode Num: 82 Episode T: 200 Reward: -126.462
# Total T: 16600 Episode Num: 83 Episode T: 200 Reward: -125.300
# Total T: 16800 Episode Num: 84 Episode T: 200 Reward: -246.835
# Total T: 17000 Episode Num: 85 Episode T: 200 Reward: -129.693
# Total T: 17200 Episode Num: 86 Episode T: 200 Reward: -122.536
# Total T: 17400 Episode Num: 87 Episode T: 200 Reward: -238.675
# Total T: 17600 Episode Num: 88 Episode T: 200 Reward: -123.973
# Total T: 17800 Episode Num: 89 Episode T: 200 Reward: -234.744
# Total T: 18000 Episode Num: 90 Episode T: 200 Reward: -247.001
# Total T: 18200 Episode Num: 91 Episode T: 200 Reward: -246.413
# Total T: 18400 Episode Num: 92 Episode T: 200 Reward: -127.712
# Total T: 18600 Episode Num: 93 Episode T: 200 Reward: -131.154
# Total T: 18800 Episode Num: 94 Episode T: 200 Reward: -130.705
# Total T: 19000 Episode Num: 95 Episode T: 200 Reward: -118.358
# Total T: 19200 Episode Num: 96 Episode T: 200 Reward: -2.277
# Total T: 19400 Episode Num: 97 Episode T: 200 Reward: -355.397
# Total T: 19600 Episode Num: 98 Episode T: 200 Reward: -329.515
# Total T: 19800 Episode Num: 99 Episode T: 200 Reward: -354.406
# Total T: 20000 Episode Num: 100 Episode T: 200 Reward: -122.534
# Total T: 20200 Episode Num: 101 Episode T: 200 Reward: -127.624
# Total T: 20400 Episode Num: 102 Episode T: 200 Reward: -127.263
# Total T: 20600 Episode Num: 103 Episode T: 200 Reward: -273.619
# Total T: 20800 Episode Num: 104 Episode T: 200 Reward: -1.288
# Total T: 21000 Episode Num: 105 Episode T: 200 Reward: -116.830
# Total T: 21200 Episode Num: 106 Episode T: 200 Reward: -237.646
# Total T: 21400 Episode Num: 107 Episode T: 200 Reward: -232.766
# Total T: 21600 Episode Num: 108 Episode T: 200 Reward: -237.532
# Total T: 21800 Episode Num: 109 Episode T: 200 Reward: -226.440
# Total T: 22000 Episode Num: 110 Episode T: 200 Reward: -238.698
# Total T: 22200 Episode Num: 111 Episode T: 200 Reward: -225.230
# Total T: 22400 Episode Num: 112 Episode T: 200 Reward: -236.076
# Total T: 22600 Episode Num: 113 Episode T: 200 Reward: -0.206
# Total T: 22800 Episode Num: 114 Episode T: 200 Reward: -120.744
# Total T: 23000 Episode Num: 115 Episode T: 200 Reward: -118.331
# Total T: 23200 Episode Num: 116 Episode T: 200 Reward: -0.232
# Total T: 23400 Episode Num: 117 Episode T: 200 Reward: -234.819
# Total T: 23600 Episode Num: 118 Episode T: 200 Reward: -118.510
# Total T: 23800 Episode Num: 119 Episode T: 200 Reward: -0.340
# Total T: 24000 Episode Num: 120 Episode T: 200 Reward: -120.528
# Total T: 24200 Episode Num: 121 Episode T: 200 Reward: -116.647
# Total T: 24400 Episode Num: 122 Episode T: 200 Reward: -115.638
# Total T: 24600 Episode Num: 123 Episode T: 200 Reward: -120.288
# Total T: 24800 Episode Num: 124 Episode T: 200 Reward: -291.296
# Total T: 25000 Episode Num: 125 Episode T: 200 Reward: -123.714
# Total T: 25200 Episode Num: 126 Episode T: 200 Reward: -348.311
# Total T: 25400 Episode Num: 127 Episode T: 200 Reward: -0.506
# Total T: 25600 Episode Num: 128 Episode T: 200 Reward: -248.738
# Total T: 25800 Episode Num: 129 Episode T: 200 Reward: -117.417
# Total T: 26000 Episode Num: 130 Episode T: 200 Reward: -118.029
# Total T: 26200 Episode Num: 131 Episode T: 200 Reward: -118.552
# Total T: 26400 Episode Num: 132 Episode T: 200 Reward: -122.523
# Total T: 26600 Episode Num: 133 Episode T: 200 Reward: -1.274
# Total T: 26800 Episode Num: 134 Episode T: 200 Reward: -126.671
# Total T: 27000 Episode Num: 135 Episode T: 200 Reward: -116.303
# Total T: 27200 Episode Num: 136 Episode T: 200 Reward: -236.254
# Total T: 27400 Episode Num: 137 Episode T: 200 Reward: -113.379
# Total T: 27600 Episode Num: 138 Episode T: 200 Reward: -121.791
# Total T: 27800 Episode Num: 139 Episode T: 200 Reward: -220.485
# Total T: 28000 Episode Num: 140 Episode T: 200 Reward: -0.751
# Total T: 28200 Episode Num: 141 Episode T: 200 Reward: -233.245
# Total T: 28400 Episode Num: 142 Episode T: 200 Reward: -233.742
# Total T: 28600 Episode Num: 143 Episode T: 200 Reward: -120.057
# Total T: 28800 Episode Num: 144 Episode T: 200 Reward: -2.550
# Total T: 29000 Episode Num: 145 Episode T: 200 Reward: -124.550
# Total T: 29200 Episode Num: 146 Episode T: 200 Reward: -1.127
# Total T: 29400 Episode Num: 147 Episode T: 200 Reward: -128.448
# Total T: 29600 Episode Num: 148 Episode T: 200 Reward: -240.320
# Total T: 29800 Episode Num: 149 Episode T: 200 Reward: -119.338
# Total T: 30000 Episode Num: 150 Episode T: 200 Reward: -229.921
# Total T: 30200 Episode Num: 151 Episode T: 200 Reward: -305.668
# Total T: 30400 Episode Num: 152 Episode T: 200 Reward: -126.380
# Total T: 30600 Episode Num: 153 Episode T: 200 Reward: -1.822
# Total T: 30800 Episode Num: 154 Episode T: 200 Reward: -338.626
# Total T: 31000 Episode Num: 155 Episode T: 200 Reward: -116.790
# Total T: 31200 Episode Num: 156 Episode T: 200 Reward: -116.861
# Total T: 31400 Episode Num: 157 Episode T: 200 Reward: -3.632
# Total T: 31600 Episode Num: 158 Episode T: 200 Reward: -119.043
# Total T: 31800 Episode Num: 159 Episode T: 200 Reward: -119.988
# Total T: 32000 Episode Num: 160 Episode T: 200 Reward: -4.022
# Total T: 32200 Episode Num: 161 Episode T: 200 Reward: -239.804
# Total T: 32400 Episode Num: 162 Episode T: 200 Reward: -120.178
# Total T: 32600 Episode Num: 163 Episode T: 200 Reward: -120.238
# Total T: 32800 Episode Num: 164 Episode T: 200 Reward: -123.034
# Total T: 33000 Episode Num: 165 Episode T: 200 Reward: -245.564
# Total T: 33200 Episode Num: 166 Episode T: 200 Reward: -2.192
# Total T: 33400 Episode Num: 167 Episode T: 200 Reward: -123.276
# Total T: 33600 Episode Num: 168 Episode T: 200 Reward: -117.671
# Total T: 33800 Episode Num: 169 Episode T: 200 Reward: -118.058
# Total T: 34000 Episode Num: 170 Episode T: 200 Reward: -332.915
# Total T: 34200 Episode Num: 171 Episode T: 200 Reward: -118.965
# Total T: 34400 Episode Num: 172 Episode T: 200 Reward: -127.325
# Total T: 34600 Episode Num: 173 Episode T: 200 Reward: -118.653
# Total T: 34800 Episode Num: 174 Episode T: 200 Reward: -130.445
# Total T: 35000 Episode Num: 175 Episode T: 200 Reward: -243.556
# Total T: 35200 Episode Num: 176 Episode T: 200 Reward: -126.081
# Total T: 35400 Episode Num: 177 Episode T: 200 Reward: -231.172
# Total T: 35600 Episode Num: 178 Episode T: 200 Reward: -119.008
# Total T: 35800 Episode Num: 179 Episode T: 200 Reward: -122.083
# Total T: 36000 Episode Num: 180 Episode T: 200 Reward: -119.051
# Total T: 36200 Episode Num: 181 Episode T: 200 Reward: -3.825
# Total T: 36400 Episode Num: 182 Episode T: 200 Reward: -225.971
# Total T: 36600 Episode Num: 183 Episode T: 200 Reward: -5.910
# Total T: 36800 Episode Num: 184 Episode T: 200 Reward: -310.468
# Total T: 37000 Episode Num: 185 Episode T: 200 Reward: -5.478
# Total T: 37200 Episode Num: 186 Episode T: 200 Reward: -120.998
# Total T: 37400 Episode Num: 187 Episode T: 200 Reward: -125.543
# Total T: 37600 Episode Num: 188 Episode T: 200 Reward: -234.424
# Total T: 37800 Episode Num: 189 Episode T: 200 Reward: -4.120
# Total T: 38000 Episode Num: 190 Episode T: 200 Reward: -231.960
# Total T: 38200 Episode Num: 191 Episode T: 200 Reward: -248.805
# Total T: 38400 Episode Num: 192 Episode T: 200 Reward: -242.695
# Total T: 38600 Episode Num: 193 Episode T: 200 Reward: -127.075
# Total T: 38800 Episode Num: 194 Episode T: 200 Reward: -119.749
# Total T: 39000 Episode Num: 195 Episode T: 200 Reward: -120.130
# Total T: 39200 Episode Num: 196 Episode T: 200 Reward: -122.657
# Total T: 39400 Episode Num: 197 Episode T: 200 Reward: -124.236
# Total T: 39600 Episode Num: 198 Episode T: 200 Reward: -123.516
# Total T: 39800 Episode Num: 199 Episode T: 200 Reward: -129.668
# Total T: 40000 Episode Num: 200 Episode T: 200 Reward: -123.866
# Total T: 40200 Episode Num: 201 Episode T: 200 Reward: -223.377
# Total T: 40400 Episode Num: 202 Episode T: 200 Reward: -124.985
# Total T: 40600 Episode Num: 203 Episode T: 200 Reward: -122.752
# Total T: 40800 Episode Num: 204 Episode T: 200 Reward: -122.298
# Total T: 41000 Episode Num: 205 Episode T: 200 Reward: -234.450
# Total T: 41200 Episode Num: 206 Episode T: 200 Reward: -243.754
# Total T: 41400 Episode Num: 207 Episode T: 200 Reward: -230.797
# Total T: 41600 Episode Num: 208 Episode T: 200 Reward: -119.690
# Total T: 41800 Episode Num: 209 Episode T: 200 Reward: -129.079
# Total T: 42000 Episode Num: 210 Episode T: 200 Reward: -5.672
# Total T: 42200 Episode Num: 211 Episode T: 200 Reward: -123.926
# Total T: 42400 Episode Num: 212 Episode T: 200 Reward: -132.500
# Total T: 42600 Episode Num: 213 Episode T: 200 Reward: -125.023
# Total T: 42800 Episode Num: 214 Episode T: 200 Reward: -233.509
# Total T: 43000 Episode Num: 215 Episode T: 200 Reward: -131.254
# Total T: 43200 Episode Num: 216 Episode T: 200 Reward: -123.544
# Total T: 43400 Episode Num: 217 Episode T: 200 Reward: -121.802
# Total T: 43600 Episode Num: 218 Episode T: 200 Reward: -6.227
# Total T: 43800 Episode Num: 219 Episode T: 200 Reward: -121.106
# Total T: 44000 Episode Num: 220 Episode T: 200 Reward: -124.276
# Total T: 44200 Episode Num: 221 Episode T: 200 Reward: -237.117
# Total T: 44400 Episode Num: 222 Episode T: 200 Reward: -5.422
# Total T: 44600 Episode Num: 223 Episode T: 200 Reward: -5.384
# Total T: 44800 Episode Num: 224 Episode T: 200 Reward: -120.501
# Total T: 45000 Episode Num: 225 Episode T: 200 Reward: -122.059
# Total T: 45200 Episode Num: 226 Episode T: 200 Reward: -126.120
# Total T: 45400 Episode Num: 227 Episode T: 200 Reward: -133.217
# Total T: 45600 Episode Num: 228 Episode T: 200 Reward: -244.806
# Total T: 45800 Episode Num: 229 Episode T: 200 Reward: -130.059
# Total T: 46000 Episode Num: 230 Episode T: 200 Reward: -244.864
# Total T: 46200 Episode Num: 231 Episode T: 200 Reward: -123.453
# Total T: 46400 Episode Num: 232 Episode T: 200 Reward: -122.568
# Total T: 46600 Episode Num: 233 Episode T: 200 Reward: -119.746
# Total T: 46800 Episode Num: 234 Episode T: 200 Reward: -7.135
# Total T: 47000 Episode Num: 235 Episode T: 200 Reward: -119.996
# Total T: 47200 Episode Num: 236 Episode T: 200 Reward: -8.979
# Total T: 47400 Episode Num: 237 Episode T: 200 Reward: -248.247
# Total T: 47600 Episode Num: 238 Episode T: 200 Reward: -126.598
# Total T: 47800 Episode Num: 239 Episode T: 200 Reward: -126.045
# Total T: 48000 Episode Num: 240 Episode T: 200 Reward: -130.476
# Total T: 48200 Episode Num: 241 Episode T: 200 Reward: -9.429
# Total T: 48400 Episode Num: 242 Episode T: 200 Reward: -129.829
# Total T: 48600 Episode Num: 243 Episode T: 200 Reward: -7.052
# Total T: 48800 Episode Num: 244 Episode T: 200 Reward: -130.428
# Total T: 49000 Episode Num: 245 Episode T: 200 Reward: -127.922
# Total T: 49200 Episode Num: 246 Episode T: 200 Reward: -6.946
# Total T: 49400 Episode Num: 247 Episode T: 200 Reward: -133.039
# Total T: 49600 Episode Num: 248 Episode T: 200 Reward: -131.615
# Total T: 49800 Episode Num: 249 Episode T: 200 Reward: -8.834
# Total T: 50000 Episode Num: 250 Episode T: 200 Reward: -244.125

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(evaluation_td3)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Pendulum with TD3')
plt.grid()
plt.show()

# %%
evaluation_sac = main(policy_name = 'SAC')
# Out:
# ---------------------------------------
# Evaluation over 10 episodes: -1407.284
# ---------------------------------------
# Total T: 200 Episode Num: 1 Episode T: 200 Reward: -1760.738
# Total T: 400 Episode Num: 2 Episode T: 200 Reward: -1246.740
# Total T: 600 Episode Num: 3 Episode T: 200 Reward: -897.289
# Total T: 800 Episode Num: 4 Episode T: 200 Reward: -972.564
# Total T: 1000 Episode Num: 5 Episode T: 200 Reward: -1352.820
# Total T: 1200 Episode Num: 6 Episode T: 200 Reward: -1627.902
# Total T: 1400 Episode Num: 7 Episode T: 200 Reward: -1354.618
# Total T: 1600 Episode Num: 8 Episode T: 200 Reward: -1337.542
# Total T: 1800 Episode Num: 9 Episode T: 200 Reward: -1194.016
# Total T: 2000 Episode Num: 10 Episode T: 200 Reward: -1567.426
# Total T: 2200 Episode Num: 11 Episode T: 200 Reward: -1156.882
# Total T: 2400 Episode Num: 12 Episode T: 200 Reward: -871.624
# Total T: 2600 Episode Num: 13 Episode T: 200 Reward: -1535.508
# Total T: 2800 Episode Num: 14 Episode T: 200 Reward: -970.373
# Total T: 3000 Episode Num: 15 Episode T: 200 Reward: -971.561
# Total T: 3200 Episode Num: 16 Episode T: 200 Reward: -1446.848
# Total T: 3400 Episode Num: 17 Episode T: 200 Reward: -693.019
# Total T: 3600 Episode Num: 18 Episode T: 200 Reward: -879.178
# Total T: 3800 Episode Num: 19 Episode T: 200 Reward: -1662.723
# Total T: 4000 Episode Num: 20 Episode T: 200 Reward: -876.022
# Total T: 4200 Episode Num: 21 Episode T: 200 Reward: -870.474
# Total T: 4400 Episode Num: 22 Episode T: 200 Reward: -906.223
# Total T: 4600 Episode Num: 23 Episode T: 200 Reward: -1278.594
# Total T: 4800 Episode Num: 24 Episode T: 200 Reward: -1616.944
# Total T: 5000 Episode Num: 25 Episode T: 200 Reward: -1349.293
# Total T: 5200 Episode Num: 26 Episode T: 200 Reward: -1528.146
# Total T: 5400 Episode Num: 27 Episode T: 200 Reward: -1116.436
# Total T: 5600 Episode Num: 28 Episode T: 200 Reward: -747.207
# Total T: 5800 Episode Num: 29 Episode T: 200 Reward: -1100.620
# Total T: 6000 Episode Num: 30 Episode T: 200 Reward: -885.808
# Total T: 6200 Episode Num: 31 Episode T: 200 Reward: -1354.708
# Total T: 6400 Episode Num: 32 Episode T: 200 Reward: -992.211
# Total T: 6600 Episode Num: 33 Episode T: 200 Reward: -1357.316
# Total T: 6800 Episode Num: 34 Episode T: 200 Reward: -941.924
# Total T: 7000 Episode Num: 35 Episode T: 200 Reward: -969.479
# Total T: 7200 Episode Num: 36 Episode T: 200 Reward: -891.210
# Total T: 7400 Episode Num: 37 Episode T: 200 Reward: -770.540
# Total T: 7600 Episode Num: 38 Episode T: 200 Reward: -1212.595
# Total T: 7800 Episode Num: 39 Episode T: 200 Reward: -1740.751
# Total T: 8000 Episode Num: 40 Episode T: 200 Reward: -1355.294
# Total T: 8200 Episode Num: 41 Episode T: 200 Reward: -970.389
# Total T: 8400 Episode Num: 42 Episode T: 200 Reward: -752.059
# Total T: 8600 Episode Num: 43 Episode T: 200 Reward: -1181.886
# Total T: 8800 Episode Num: 44 Episode T: 200 Reward: -1566.919
# Total T: 9000 Episode Num: 45 Episode T: 200 Reward: -1548.711
# Total T: 9200 Episode Num: 46 Episode T: 200 Reward: -1661.898
# Total T: 9400 Episode Num: 47 Episode T: 200 Reward: -1513.122
# Total T: 9600 Episode Num: 48 Episode T: 200 Reward: -1287.683
# Total T: 9800 Episode Num: 49 Episode T: 200 Reward: -1552.121
# Total T: 10000 Episode Num: 50 Episode T: 200 Reward: -986.745
# Total T: 10200 Episode Num: 51 Episode T: 200 Reward: -1087.160
# Total T: 10400 Episode Num: 52 Episode T: 200 Reward: -1671.372
# Total T: 10600 Episode Num: 53 Episode T: 200 Reward: -1640.314
# Total T: 10800 Episode Num: 54 Episode T: 200 Reward: -1851.470
# Total T: 11000 Episode Num: 55 Episode T: 200 Reward: -1603.832
# Total T: 11200 Episode Num: 56 Episode T: 200 Reward: -1569.374
# Total T: 11400 Episode Num: 57 Episode T: 200 Reward: -1433.915
# Total T: 11600 Episode Num: 58 Episode T: 200 Reward: -1442.287
# Total T: 11800 Episode Num: 59 Episode T: 200 Reward: -1250.950
# Total T: 12000 Episode Num: 60 Episode T: 200 Reward: -1003.480
# Total T: 12200 Episode Num: 61 Episode T: 200 Reward: -1231.085
# Total T: 12400 Episode Num: 62 Episode T: 200 Reward: -659.570
# Total T: 12600 Episode Num: 63 Episode T: 200 Reward: -804.724
# Total T: 12800 Episode Num: 64 Episode T: 200 Reward: -393.816
# Total T: 13000 Episode Num: 65 Episode T: 200 Reward: -129.154
# Total T: 13200 Episode Num: 66 Episode T: 200 Reward: -256.068
# Total T: 13400 Episode Num: 67 Episode T: 200 Reward: -125.714
# Total T: 13600 Episode Num: 68 Episode T: 200 Reward: -119.912
# Total T: 13800 Episode Num: 69 Episode T: 200 Reward: -353.664
# Total T: 14000 Episode Num: 70 Episode T: 200 Reward: -2.867
# Total T: 14200 Episode Num: 71 Episode T: 200 Reward: -254.697
# Total T: 14400 Episode Num: 72 Episode T: 200 Reward: -4.329
# Total T: 14600 Episode Num: 73 Episode T: 200 Reward: -263.664
# Total T: 14800 Episode Num: 74 Episode T: 200 Reward: -3.699
# Total T: 15000 Episode Num: 75 Episode T: 200 Reward: -349.743
# Total T: 15200 Episode Num: 76 Episode T: 200 Reward: -239.319
# Total T: 15400 Episode Num: 77 Episode T: 200 Reward: -121.590
# Total T: 15600 Episode Num: 78 Episode T: 200 Reward: -247.072
# Total T: 15800 Episode Num: 79 Episode T: 200 Reward: -248.107
# Total T: 16000 Episode Num: 80 Episode T: 200 Reward: -124.747
# Total T: 16200 Episode Num: 81 Episode T: 200 Reward: -1.009
# Total T: 16400 Episode Num: 82 Episode T: 200 Reward: -119.823
# Total T: 16600 Episode Num: 83 Episode T: 200 Reward: -121.642
# Total T: 16800 Episode Num: 84 Episode T: 200 Reward: -235.349
# Total T: 17000 Episode Num: 85 Episode T: 200 Reward: -125.300
# Total T: 17200 Episode Num: 86 Episode T: 200 Reward: -121.239
# Total T: 17400 Episode Num: 87 Episode T: 200 Reward: -229.870
# Total T: 17600 Episode Num: 88 Episode T: 200 Reward: -119.886
# Total T: 17800 Episode Num: 89 Episode T: 200 Reward: -225.919
# Total T: 18000 Episode Num: 90 Episode T: 200 Reward: -245.639
# Total T: 18200 Episode Num: 91 Episode T: 200 Reward: -243.341
# Total T: 18400 Episode Num: 92 Episode T: 200 Reward: -120.297
# Total T: 18600 Episode Num: 93 Episode T: 200 Reward: -128.666
# Total T: 18800 Episode Num: 94 Episode T: 200 Reward: -127.666
# Total T: 19000 Episode Num: 95 Episode T: 200 Reward: -117.550
# Total T: 19200 Episode Num: 96 Episode T: 200 Reward: -0.890
# Total T: 19400 Episode Num: 97 Episode T: 200 Reward: -366.126
# Total T: 19600 Episode Num: 98 Episode T: 200 Reward: -339.505
# Total T: 19800 Episode Num: 99 Episode T: 200 Reward: -366.225
# Total T: 20000 Episode Num: 100 Episode T: 200 Reward: -120.159
# Total T: 20200 Episode Num: 101 Episode T: 200 Reward: -121.423
# Total T: 20400 Episode Num: 102 Episode T: 200 Reward: -124.941
# Total T: 20600 Episode Num: 103 Episode T: 200 Reward: -306.307
# Total T: 20800 Episode Num: 104 Episode T: 200 Reward: -0.603
# Total T: 21000 Episode Num: 105 Episode T: 200 Reward: -116.609
# Total T: 21200 Episode Num: 106 Episode T: 200 Reward: -245.117
# Total T: 21400 Episode Num: 107 Episode T: 200 Reward: -231.766
# Total T: 21600 Episode Num: 108 Episode T: 200 Reward: -235.396
# Total T: 21800 Episode Num: 109 Episode T: 200 Reward: -231.023
# Total T: 22000 Episode Num: 110 Episode T: 200 Reward: -247.197
# Total T: 22200 Episode Num: 111 Episode T: 200 Reward: -226.203
# Total T: 22400 Episode Num: 112 Episode T: 200 Reward: -232.174
# Total T: 22600 Episode Num: 113 Episode T: 200 Reward: -0.613
# Total T: 22800 Episode Num: 114 Episode T: 200 Reward: -120.714
# Total T: 23000 Episode Num: 115 Episode T: 200 Reward: -119.291
# Total T: 23200 Episode Num: 116 Episode T: 200 Reward: -0.726
# Total T: 23400 Episode Num: 117 Episode T: 200 Reward: -234.526
# Total T: 23600 Episode Num: 118 Episode T: 200 Reward: -119.730
# Total T: 23800 Episode Num: 119 Episode T: 200 Reward: -1.010
# Total T: 24000 Episode Num: 120 Episode T: 200 Reward: -123.112
# Total T: 24200 Episode Num: 121 Episode T: 200 Reward: -117.336
# Total T: 24400 Episode Num: 122 Episode T: 200 Reward: -117.107
# Total T: 24600 Episode Num: 123 Episode T: 200 Reward: -120.503
# Total T: 24800 Episode Num: 124 Episode T: 200 Reward: -248.667
# Total T: 25000 Episode Num: 125 Episode T: 200 Reward: -123.874
# Total T: 25200 Episode Num: 126 Episode T: 200 Reward: -338.485
# Total T: 25400 Episode Num: 127 Episode T: 200 Reward: -0.663
# Total T: 25600 Episode Num: 128 Episode T: 200 Reward: -240.711
# Total T: 25800 Episode Num: 129 Episode T: 200 Reward: -119.260
# Total T: 26000 Episode Num: 130 Episode T: 200 Reward: -118.398
# Total T: 26200 Episode Num: 131 Episode T: 200 Reward: -119.626
# Total T: 26400 Episode Num: 132 Episode T: 200 Reward: -123.133
# Total T: 26600 Episode Num: 133 Episode T: 200 Reward: -1.180
# Total T: 26800 Episode Num: 134 Episode T: 200 Reward: -125.072
# Total T: 27000 Episode Num: 135 Episode T: 200 Reward: -116.914
# Total T: 27200 Episode Num: 136 Episode T: 200 Reward: -235.176
# Total T: 27400 Episode Num: 137 Episode T: 200 Reward: -113.504
# Total T: 27600 Episode Num: 138 Episode T: 200 Reward: -247.082
# Total T: 27800 Episode Num: 139 Episode T: 200 Reward: -222.024
# Total T: 28000 Episode Num: 140 Episode T: 200 Reward: -0.749
# Total T: 28200 Episode Num: 141 Episode T: 200 Reward: -235.813
# Total T: 28400 Episode Num: 142 Episode T: 200 Reward: -230.758
# Total T: 28600 Episode Num: 143 Episode T: 200 Reward: -121.414
# Total T: 28800 Episode Num: 144 Episode T: 200 Reward: -2.147
# Total T: 29000 Episode Num: 145 Episode T: 200 Reward: -125.236
# Total T: 29200 Episode Num: 146 Episode T: 200 Reward: -0.856
# Total T: 29400 Episode Num: 147 Episode T: 200 Reward: -127.338
# Total T: 29600 Episode Num: 148 Episode T: 200 Reward: -236.822
# Total T: 29800 Episode Num: 149 Episode T: 200 Reward: -120.724
# Total T: 30000 Episode Num: 150 Episode T: 200 Reward: -231.714
# Total T: 30200 Episode Num: 151 Episode T: 200 Reward: -247.667
# Total T: 30400 Episode Num: 152 Episode T: 200 Reward: -125.374
# Total T: 30600 Episode Num: 153 Episode T: 200 Reward: -1.900
# Total T: 30800 Episode Num: 154 Episode T: 200 Reward: -343.444
# Total T: 31000 Episode Num: 155 Episode T: 200 Reward: -117.051
# Total T: 31200 Episode Num: 156 Episode T: 200 Reward: -118.821
# Total T: 31400 Episode Num: 157 Episode T: 200 Reward: -3.868
# Total T: 31600 Episode Num: 158 Episode T: 200 Reward: -119.960
# Total T: 31800 Episode Num: 159 Episode T: 200 Reward: -122.956
# Total T: 32000 Episode Num: 160 Episode T: 200 Reward: -3.739
# Total T: 32200 Episode Num: 161 Episode T: 200 Reward: -243.633
# Total T: 32400 Episode Num: 162 Episode T: 200 Reward: -120.979
# Total T: 32600 Episode Num: 163 Episode T: 200 Reward: -120.144
# Total T: 32800 Episode Num: 164 Episode T: 200 Reward: -124.016
# Total T: 33000 Episode Num: 165 Episode T: 200 Reward: -246.642
# Total T: 33200 Episode Num: 166 Episode T: 200 Reward: -1.376
# Total T: 33400 Episode Num: 167 Episode T: 200 Reward: -124.400
# Total T: 33600 Episode Num: 168 Episode T: 200 Reward: -117.765
# Total T: 33800 Episode Num: 169 Episode T: 200 Reward: -117.984
# Total T: 34000 Episode Num: 170 Episode T: 200 Reward: -322.789
# Total T: 34200 Episode Num: 171 Episode T: 200 Reward: -119.877
# Total T: 34400 Episode Num: 172 Episode T: 200 Reward: -126.598
# Total T: 34600 Episode Num: 173 Episode T: 200 Reward: -118.594
# Total T: 34800 Episode Num: 174 Episode T: 200 Reward: -130.530
# Total T: 35000 Episode Num: 175 Episode T: 200 Reward: -244.492
# Total T: 35200 Episode Num: 176 Episode T: 200 Reward: -125.203
# Total T: 35400 Episode Num: 177 Episode T: 200 Reward: -227.568
# Total T: 35600 Episode Num: 178 Episode T: 200 Reward: -118.993
# Total T: 35800 Episode Num: 179 Episode T: 200 Reward: -123.608
# Total T: 36000 Episode Num: 180 Episode T: 200 Reward: -117.111
# Total T: 36200 Episode Num: 181 Episode T: 200 Reward: -1.230
# Total T: 36400 Episode Num: 182 Episode T: 200 Reward: -225.148
# Total T: 36600 Episode Num: 183 Episode T: 200 Reward: -3.353
# Total T: 36800 Episode Num: 184 Episode T: 200 Reward: -305.842
# Total T: 37000 Episode Num: 185 Episode T: 200 Reward: -2.231
# Total T: 37200 Episode Num: 186 Episode T: 200 Reward: -119.350
# Total T: 37400 Episode Num: 187 Episode T: 200 Reward: -122.603
# Total T: 37600 Episode Num: 188 Episode T: 200 Reward: -232.484
# Total T: 37800 Episode Num: 189 Episode T: 200 Reward: -1.452
# Total T: 38000 Episode Num: 190 Episode T: 200 Reward: -229.793
# Total T: 38200 Episode Num: 191 Episode T: 200 Reward: -248.168
# Total T: 38400 Episode Num: 192 Episode T: 200 Reward: -238.431
# Total T: 38600 Episode Num: 193 Episode T: 200 Reward: -126.103
# Total T: 38800 Episode Num: 194 Episode T: 200 Reward: -116.413
# Total T: 39000 Episode Num: 195 Episode T: 200 Reward: -116.567
# Total T: 39200 Episode Num: 196 Episode T: 200 Reward: -121.191
# Total T: 39400 Episode Num: 197 Episode T: 200 Reward: -123.110
# Total T: 39600 Episode Num: 198 Episode T: 200 Reward: -120.807
# Total T: 39800 Episode Num: 199 Episode T: 200 Reward: -126.033
# Total T: 40000 Episode Num: 200 Episode T: 200 Reward: -121.601
# Total T: 40200 Episode Num: 201 Episode T: 200 Reward: -223.832
# Total T: 40400 Episode Num: 202 Episode T: 200 Reward: -124.044
# Total T: 40600 Episode Num: 203 Episode T: 200 Reward: -121.175
# Total T: 40800 Episode Num: 204 Episode T: 200 Reward: -119.306
# Total T: 41000 Episode Num: 205 Episode T: 200 Reward: -232.964
# Total T: 41200 Episode Num: 206 Episode T: 200 Reward: -360.582
# Total T: 41400 Episode Num: 207 Episode T: 200 Reward: -229.912
# Total T: 41600 Episode Num: 208 Episode T: 200 Reward: -114.967
# Total T: 41800 Episode Num: 209 Episode T: 200 Reward: -125.910
# Total T: 42000 Episode Num: 210 Episode T: 200 Reward: -1.337
# Total T: 42200 Episode Num: 211 Episode T: 200 Reward: -120.158
# Total T: 42400 Episode Num: 212 Episode T: 200 Reward: -126.510
# Total T: 42600 Episode Num: 213 Episode T: 200 Reward: -122.511
# Total T: 42800 Episode Num: 214 Episode T: 200 Reward: -235.548
# Total T: 43000 Episode Num: 215 Episode T: 200 Reward: -127.231
# Total T: 43200 Episode Num: 216 Episode T: 200 Reward: -122.219
# Total T: 43400 Episode Num: 217 Episode T: 200 Reward: -119.684
# Total T: 43600 Episode Num: 218 Episode T: 200 Reward: -1.764
# Total T: 43800 Episode Num: 219 Episode T: 200 Reward: -119.514
# Total T: 44000 Episode Num: 220 Episode T: 200 Reward: -121.672
# Total T: 44200 Episode Num: 221 Episode T: 200 Reward: -236.631
# Total T: 44400 Episode Num: 222 Episode T: 200 Reward: -1.799
# Total T: 44600 Episode Num: 223 Episode T: 200 Reward: -0.736
# Total T: 44800 Episode Num: 224 Episode T: 200 Reward: -117.314
# Total T: 45000 Episode Num: 225 Episode T: 200 Reward: -119.531
# Total T: 45200 Episode Num: 226 Episode T: 200 Reward: -122.714
# Total T: 45400 Episode Num: 227 Episode T: 200 Reward: -125.361
# Total T: 45600 Episode Num: 228 Episode T: 200 Reward: -240.870
# Total T: 45800 Episode Num: 229 Episode T: 200 Reward: -124.519
# Total T: 46000 Episode Num: 230 Episode T: 200 Reward: -239.718
# Total T: 46200 Episode Num: 231 Episode T: 200 Reward: -118.302
# Total T: 46400 Episode Num: 232 Episode T: 200 Reward: -116.924
# Total T: 46600 Episode Num: 233 Episode T: 200 Reward: -115.014
# Total T: 46800 Episode Num: 234 Episode T: 200 Reward: -0.769
# Total T: 47000 Episode Num: 235 Episode T: 200 Reward: -114.981
# Total T: 47200 Episode Num: 236 Episode T: 200 Reward: -1.550
# Total T: 47400 Episode Num: 237 Episode T: 200 Reward: -244.179
# Total T: 47600 Episode Num: 238 Episode T: 200 Reward: -119.049
# Total T: 47800 Episode Num: 239 Episode T: 200 Reward: -119.825
# Total T: 48000 Episode Num: 240 Episode T: 200 Reward: -123.842
# Total T: 48200 Episode Num: 241 Episode T: 200 Reward: -1.139
# Total T: 48400 Episode Num: 242 Episode T: 200 Reward: -124.828
# Total T: 48600 Episode Num: 243 Episode T: 200 Reward: -2.076
# Total T: 48800 Episode Num: 244 Episode T: 200 Reward: -125.808
# Total T: 49000 Episode Num: 245 Episode T: 200 Reward: -122.759
# Total T: 49200 Episode Num: 246 Episode T: 200 Reward: -1.950
# Total T: 49400 Episode Num: 247 Episode T: 200 Reward: -125.171
# Total T: 49600 Episode Num: 248 Episode T: 200 Reward: -125.778
# Total T: 49800 Episode Num: 249 Episode T: 200 Reward: -2.399
# Total T: 50000 Episode Num: 250 Episode T: 200 Reward: -241.051

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(evaluation_sac)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Pendulum with SAC')
plt.grid()
plt.show()
